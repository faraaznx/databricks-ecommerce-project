# %%
from pyspark.sql.functions import to_date, col, round, current_timestamp
import sys
from time import time

# %%
# sys.path.append("/Workspace/Users/faraaz_khan@epam.com/PEI/utils")

# %%
# from utils.common_util

# %%
start_time = time()

# %%
checkpoint_path = "/Volumes/fz_catalog/landing/_checkpoints/products_silver/"

# %%
#need a try except block to check if these columns are present in bronze or not

df = (
    spark.readStream
         .format("delta")
         .table("fz_catalog.bronze.products")
         .select("product_id", "category", "sub_category")
)

# %%
df_silver = df.withColumn("created_date", current_timestamp())

# %%
df_silver.writeStream.format("delta")\
.outputMode("append")\
.option("checkpointLocation", checkpoint_path)\
.trigger(availableNow=True)\
.toTable("fz_catalog.silver.products")

# %%
end_time = time()

# %%
dbutils.notebook.exit(f"Run Time: {end_time - start_time} seconds")
